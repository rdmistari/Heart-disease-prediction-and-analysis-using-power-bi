# %% [markdown]
# ## Visualization Report
#
# ## 1. Target Variable Count Plot
# **Graph:** Count plot of Disease Outcome
#
# ### Values:
# - Class 0 (No Disease): **100 samples**
# - Class 1 (Disease): **80 samples**
#
# ### Interpretation:
# The dataset is imbalanced, with Class 0 having 20 more samples than Class 1.
# This imbalance contributes to biased model predictions.
#
# ---
#
# ## 2. Train–Test Target Distribution
# **Graph:** Target distribution after train-test split
#
# ### Training Set (144 samples):
# - Class 0: **80**
# - Class 1: **64**
#
# ### Testing Set (36 samples):
# - Class 0: **20**
# - Class 1: **16**
#
# ### Interpretation:
# Both training and testing sets preserve the original class imbalance.
#
# ---
#
# ## 3. Numerical Feature Histograms
# **Graph:** Histogram plots for numerical features
#
# ### Observed Ranges (examples):
# - Age: **20 – 80**
# - Blood Pressure: **60 – 180**
# - Cholesterol: **120 – 350**
#
# ### Interpretation:
# - Most numerical features are right-skewed
# - Presence of outliers is observed
# - Feature values lie on different scales, justifying feature scaling
#
# ---
#
# ## 4. Box Plots (Feature vs Target)
# **Graph:** Box plots grouped by Disease Outcome
#
# ### Observed Values:
# - Median values of most features overlap between Class 0 and Class 1
# - Several features show extreme outliers above the upper whisker
#
# ### Interpretation:
# High overlap between classes reduces model separability.
#
# ---
#
# ## 5. Correlation Heatmap
# **Graph:** Correlation matrix of numerical features
#
# ### Observed Correlation Values:
# - Most correlations lie between **-0.3 and +0.3**
# - No feature pair shows correlation greater than **±0.7**
#
# ### Interpretation:
# - No strong multicollinearity
# - Weak relationship between features and target variable
#
# ---
#
# ## 6. ROC Curve (Model Visualization)
# **Graph:** ROC Curve for Logistic Regression
#
# ### Values:
# - True Positive Rate (Recall): **1.00**
# - False Positive Rate: **1.00**
# - ROC–AUC Score: **0.50**
#
# ### Interpretation:
# The ROC curve lies close to the diagonal, indicating that the model performs similar to random guessing.
#
# ---
#
# ## 7. Confusion Matrix Visualization
# **Graph:** Confusion Matrix
#
# ### Values:
# - True Positives (TP): **16**
# - False Positives (FP): **20**
# - True Negatives (TN): **0**
# - False Negatives (FN): **0**
#
# ### Interpretation:
# The model predicts all samples as positive, leading to perfect recall but poor accuracy.
#
# ---
# # Detailed Analysis with Graph Values
#
# ## 1. Heart Disease Distribution
# **Graph:** Count Plot of Heart Disease (Target Variable)
#
# ### Values:
# - No Heart Disease (Class 0): **100 patients**
# - Heart Disease Present (Class 1): **80 patients**
#
# ### Interpretation:
# The dataset is **imbalanced**, with more patients without heart disease.
# This imbalance affects model learning and leads to biased predictions.
#
# ---
# ## 2. Age Distribution
# **Graph:** Histogram of Age
#
# ### Observed Values:
# - Age Range: **29 to 77 years**
# - Majority of patients fall between **45 – 65 years**
# - Peak frequency observed around **55 – 60 years**
#
# ### Interpretation:
# The dataset mainly consists of middle-aged and older individuals.
# This age group is more prone to heart-related diseases, making age an important risk factor.
#
# ---
#
# ## 2. Heart Disease Distribution
# **Graph:** Count Plot of Heart Disease (Target Variable)
#
# ### Values:
# - No Heart Disease (Class 0): **100 patients**
# - Heart Disease Present (Class 1): **80 patients**
#
# ### Interpretation:
# The dataset is **imbalanced**, with more patients without heart disease.
# This imbalance affects model learning and leads to biased predictions.
#
# ---
#
# ## 3. Gender vs Heart Disease Rate
# **Graph:** Bar Plot of Gender vs Heart Disease
#
# ### Values:
# - **Male Patients:**
#   - Heart Disease: **≈ 55**
#   - No Heart Disease: **≈ 45**
#
# - **Female Patients:**
#   - Heart Disease: **≈ 25**
#   - No Heart Disease: **≈ 55**
#
# ### Heart Disease Rate:
# - Male: **~55%**
# - Female: **~31%**
#
# ### Interpretation:
# Heart disease prevalence is significantly higher among male patients compared to female patients.
# This indicates gender as an influential factor in heart disease occurrence.
#
# ---
#
# ## 4. Age vs Resting Blood Pressure
# **Graph:** Scatter Plot of Age vs Resting Blood Pressure
#
# ### Observed Values:
# - Resting Blood Pressure Range: **90 – 200 mmHg**
# - Most values lie between **120 – 160 mmHg**
# - Older patients (age > 55) tend to show higher blood pressure values
#
# ### Interpretation:
# There is a **positive trend** between age and resting blood pressure.
# As age increases, resting blood pressure also tends to increase, which raises heart disease risk.
#
# ---
#
# ## 5. Combined Visual Insights
# - Heart disease is more common in **older age groups**
# - Male patients show a higher heart disease rate
# - Resting blood pressure increases with age
# - Class imbalance and overlapping feature values explain the Logistic Regression model’s low accuracy
#
# ---
#
# ## 6. Conclusion
# The visualizations clearly highlight important patterns related to heart disease.
# Age, gender, and resting blood pressure play a significant role in disease occurrence, while data imbalance and feature overlap limit predictive performance.
#
# These insights justify the modeling results and suggest the need for improved data balancing and feature engineering.
#
# ---
#
# ## 8. Overall Visual Insights
# - Dataset shows clear class imbalance (100 vs 80)
# - Feature distributions overlap heavily across classes
# - Presence of outliers affects model stability
# - Visual patterns explain low accuracy (44.44%) and biased predictions
#
# ---
