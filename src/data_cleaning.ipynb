# %% [markdown]
# ### **Data Cleaning**

# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder

# %%
df1 = pd.read_csv(r"C:\Users\Sanjana\Downloads\labels.csv")
df1
# Out:
#     patient_id  heart_disease_present
# 0       0z64un                      0
# 1       ryoo3j                      0
# 2       yt1s1x                      1
# 3       l2xjde                      1
# 4       oyt4ek                      0
# ..         ...                    ...
# 175     5qfar3                      1
# 176     2s2b1f                      1
# 177     nsd00i                      1
# 178     0xw93k                      0
# 179     2nx10r                      0
#
# [180 rows x 2 columns]

# %%
clean_df1 = df1.copy()

# %%
le = LabelEncoder()
clean_df1["patient_id_encoded"] = le.fit_transform(clean_df1["patient_id"])

# %%
clean_df1.to_csv("labels_cleaned_encoded.csv", index=False)

# %%
print("Dataset cleaned and encoded successfully!")
print(clean_df1.head())
# Out:
# Dataset cleaned and encoded successfully!
#   patient_id  heart_disease_present  patient_id_encoded
# 0     0z64un                      0                   6
# 1     ryoo3j                      0                 147
# 2     yt1s1x                      1                 172
# 3     l2xjde                      1                 112
# 4     oyt4ek                      0                 133

# %%
df1.shape
# Out:
# (180, 2)

# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder

# %%
df2 = pd.read_csv(r"C:\Users\Sanjana\Downloads\values.csv")
df2
# Out:
#     patient_id  slope_of_peak_exercise_st_segment               thal  \
# 0       0z64un                                  1             normal
# 1       ryoo3j                                  2             normal
# 2       yt1s1x                                  1             normal
# 3       l2xjde                                  1  reversible_defect
# 4       oyt4ek                                  3  reversible_defect
# ..         ...                                ...                ...
# 175     5qfar3                                  2  reversible_defect
# 176     2s2b1f                                  2             normal
# 177     nsd00i                                  2  reversible_defect
# 178     0xw93k                                  1             normal
# 179     2nx10r                                  1             normal
#
#      resting_blood_pressure  chest_pain_type  num_major_vessels  \
# 0                       128                2                  0
# ...

# %%
clean_df2 = df2.copy()

# %%
le1 = LabelEncoder()
clean_df2["patient_id_encoded"] = le1.fit_transform(clean_df2["patient_id"])

# %%
le2 = LabelEncoder()
clean_df2["thal_encoded"] = le2.fit_transform(clean_df2["thal"])

# %%
le2 = LabelEncoder()
clean_df2["thal_encoded"] = le2.fit_transform(clean_df2["thal"])

# %%
clean_df2.to_csv("values_cleaned_encoded.csv", index=False)

# %%
print("Dataset cleaned and encoded successfully!")
print(clean_df2.head())
# Out:
# Dataset cleaned and encoded successfully!
#   patient_id  slope_of_peak_exercise_st_segment               thal  \
# 0     0z64un                                  1             normal
# 1     ryoo3j                                  2             normal
# 2     yt1s1x                                  1             normal
# 3     l2xjde                                  1  reversible_defect
# 4     oyt4ek                                  3  reversible_defect
#
#    resting_blood_pressure  chest_pain_type  num_major_vessels  \
# 0                     128                2                  0
# 1                     110                3                  0
# 2                     125                4                  3
# 3                     152                4                  0
# 4                     178                1                  0
#
#    fasting_blood_sugar_gt_120_mg_per_dl  resting_ekg_results  \
# 0                                     0                    2
# ...

# %%
df2.shape
# Out:
# (180, 14)

# %%
import pandas as pd

# %%
labels = pd.read_csv("labels_cleaned_encoded.csv")

# %%
values = pd.read_csv("values_cleaned_encoded.csv")

# %%
merged_df = pd.merge(
    values, 
    labels[["patient_id_encoded", "heart_disease_present"]], 
    on="patient_id_encoded",
    how="inner"
)

# %%
merged_df.to_csv("final_merged_dataset.csv", index=False)

# %%
print("final_merged_dataset.csv saved successfully!")
# Out:
# final_merged_dataset.csv saved successfully!

# %%
merged_df = pd.read_csv(r"C:\Users\Sanjana\Downloads\final_merged_dataset.csv")
merged_df
# Out:
#     patient_id  slope_of_peak_exercise_st_segment               thal  \
# 0       0z64un                                  1             normal
# 1       ryoo3j                                  2             normal
# 2       yt1s1x                                  1             normal
# 3       l2xjde                                  1  reversible_defect
# 4       oyt4ek                                  3  reversible_defect
# ..         ...                                ...                ...
# 175     5qfar3                                  2  reversible_defect
# 176     2s2b1f                                  2             normal
# 177     nsd00i                                  2  reversible_defect
# 178     0xw93k                                  1             normal
# 179     2nx10r                                  1             normal
#
#      resting_blood_pressure  chest_pain_type  num_major_vessels  \
# 0                       128                2                  0
# ...

# %%
merged_df.shape
# Out:
# (180, 17)

# %% [markdown]
# ## What the Dataset is About
#
# This dataset contains clinical patient data used to predict whether a person has heart disease.
# It includes medical measurements such as age, blood pressure, cholesterol, ECG results,
# and other health-related features used for heart disease prediction.
#
# ---
#
# ## Dataset Shapes
#
# ### A. values.csv
# - **Shape:** `(180 rows × 14 columns)`
# - **Meaning:**
#   - 180 patient records
#   - 14 clinical measurement features
#   - These features are used as input variables for the model
#
# ---
#
# ### B. labels.csv
# - **Shape:** `(180 rows × 3 columns)`
# - **Meaning:**
#   - 180 patients
#   - Columns include:
#     - Patient ID
#     - Target variable (Heart Disease)
#     - Additional label-related identifier
#
# ---
#
# ## Merged Dataset (After Combining Both Files)
#
# The `values.csv` file (14 features) was merged with `labels.csv` (3 columns)
# using a common patient identifier.
#
# - **Total columns before cleaning:**
#   `14 + 3 = 17 columns`
#
# - **Description:**
#   - Clinical features and target labels are combined into a single dataset
#   - This merged dataset is used for data cleaning and encoding
#
# ---
#
# ## Data Cleaning and Encoding Performed
#
# ### 1. Dataset Copy
# - A copy of the merged dataset was created to keep the original data unchanged
#
# ### 2. Label Encoding
# - Categorical columns were converted into numerical format
# - **LabelEncoder** was used for encoding
# - Encoding was required because machine learning models accept only numerical input
#
# ### 3. Data Validation
# - The encoded dataset was verified for correctness
# - Column count and data consistency were rechecked
#
# ---
#
# ## Final Dataset Summary
# - Dataset contains **180 rows and 17 columns**
# - All required features and target labels are present
# - Categorical values are successfully encoded
# - Dataset is ready for further preprocessing, EDA, and model training
#
# ---
#
# ## Conclusion
# This notebook focuses on merging, cleaning, and encoding the dataset.
# After preprocessing, the data becomes structured and suitable for
# machine learning models used in heart disease prediction.
